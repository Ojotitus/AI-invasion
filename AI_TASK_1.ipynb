# %%
#IMPORTING OF LAB
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import sklearn 

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_train = pd.read_csv("/content/drive/MyDrive/DSN_TASK 1/Train.csv")
df_train.head(10)
# Out:
#   VehicleID Location          Maker                Model   Year  Colour  \
# 0  VHL12546    Abuja          Honda  Accord Coupe EX V-6  2,011  Silver
# 1  VHL18827   Ibadan        Hyundai               Sonata  2,012  Silver
# 2  VHL19499    Lagos          Lexus               RX 350  2,010     Red
# 3  VHL17991    Abuja  Mercedes-Benz            GLE-Class  2,017    Blue
# 4  VHL12170   Ibadan         Toyota           Highlander  2,002     Red
# 5  VHL19996    Lagos         Toyota             Venza V6  2,011   Black
# 6  VHL16314    Lagos          Lexus           LX 570 AWD  2,019   Black
# 7  VHL14299    Abuja         Toyota               Avalon  2,015    Gold
# 8  VHL15637    Lagos         Toyota               Sienna  2,012    Blue
# 9  VHL15752   Ibadan  Mercedes-Benz            C240 Matt  2,004   Black
#
#    Amount (Million Naira)           Type Distance
# 0                    2.20  Nigerian Used      NaN
# 1                    3.50  Nigerian Used  125,000
# ...

# %%
df_test = pd.read_csv("/content/drive/MyDrive/DSN_TASK 1/Test.csv")
df_test.head(10)
# Out:
#   VehicleID Location          Maker                  Model   Year Colour  \
# 0  VHL18518    Abuja            BMW                   323i  2,008  White
# 1  VHL17149    Lagos         Toyota                  Camry  2,013  White
# 2  VHL10927    Lagos         Toyota  Highlander Limited V6  2,005   Gold
# 3  VHL12909    Lagos         Toyota                  Camry  2,011   Gray
# 4  VHL12348    Lagos          Lexus             ES 350 FWD  2,013    Red
# 5  VHL10798    Lagos  Mercedes-Benz              GLE-Class  2,017  Black
# 6  VHL11022    Abuja         Toyota          Sienna LE 4dr  1,999   Gold
# 7  VHL12206    Lagos          Lexus                 ES 350  2,011    Red
# 8  VHL11697    Abuja          Honda                   CR-V  2,017  White
# 9  VHL12313    Lagos         Toyota                  Camry  2,013  Black
#
#            Type  Distance
# 0  Foreign Used   30524.0
# 1  Foreign Used       NaN
# 2  Foreign Used       NaN
# 3  Foreign Used  166839.0
# 4  Foreign Used   88862.0
# ...

# %%
df_train.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7184 non-null   object
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7188 non-null   float64
#  7   Type                    7008 non-null   object
#  8   Distance                4845 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 506.7+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2059 non-null   object
#  5   Colour     2061 non-null   object
#  6   Type       2007 non-null   object
#  7   Distance   1385 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 128.9+ KB

# %%
#checking for missing values
df_train.isnull() .sum()
# Out:
# VehicleID                    0
# Location                     0
# Maker                        0
# Model                        0
# Year                        21
# Colour                       0
# Amount (Million Naira)      17
# Type                       197
# Distance                  2360
# dtype: int64

# %%
df_test.isnull() .sum()
# Out:
# VehicleID      0
# Location       0
# Maker          0
# Model          0
# Year           2
# Colour         0
# Type          54
# Distance     676
# dtype: int64

# %%
print("Before convertion", df_train.Year)
df_train.Year = [("".join (str(i).split(",")))for i in df_train.Year]
print ("After convertion", df_train.Year)
#converting df_train.Year to str and remove comma in the year
# Out:
# Before convertion 0       2,011
# 1       2,012
# 2       2,010
# 3       2,017
# 4       2,002
#         ...
# 7200    2,018
# 7201    2,007
# 7202    2,010
# 7203    2,012
# 7204    2,012
# Name: Year, Length: 7205, dtype: object
# After convertion 0       2011
# 1       2012
# 2       2010
# 3       2017
# 4       2002
#         ...
# 7200    2018
# 7201    2007
# 7202    2010
# 7203    2012
# 7204    2012
# Name: Year, Length: 7205, dtype: object

# %%
print("Before convertion", df_train.Distance)
df_train.Distance = [("".join (str(i).split(",")))for i in df_train.Distance]
print ("After convertion", df_train.Distance)
# Out:
# Before convertion 0           NaN
# 1       125,000
# 2       110,852
# 3        30,000
# 4       125,206
#          ...
# 7200     65,000
# 7201    200,000
# 7202        NaN
# 7203     85,750
# 7204     83,308
# Name: Distance, Length: 7205, dtype: object
# After convertion 0          nan
# 1       125000
# 2       110852
# 3        30000
# 4       125206
#          ...
# 7200     65000
# 7201    200000
# 7202       nan
# 7203     85750
# 7204     83308
# Name: Distance, Length: 7205, dtype: object

# %%
print("Before convertion", df_test.Year)
df_test.Year = [("".join (str(i).split(",")))for i in df_test.Year]
print ("After convertion", df_test.Year)
# Out:
# Before convertion 0       2,008
# 1       2,013
# 2       2,005
# 3       2,011
# 4       2,013
#         ...
# 2056    2,020
# 2057    2,011
# 2058    2,015
# 2059    2,013
# 2060    2,009
# Name: Year, Length: 2061, dtype: object
# After convertion 0       2008
# 1       2013
# 2       2005
# 3       2011
# 4       2013
#         ...
# 2056    2020
# 2057    2011
# 2058    2015
# 2059    2013
# 2060    2009
# Name: Year, Length: 2061, dtype: object

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2061 non-null   object
#  5   Colour     2061 non-null   object
#  6   Type       2007 non-null   object
#  7   Distance   1385 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 128.9+ KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7205 non-null   object
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7188 non-null   float64
#  7   Type                    7008 non-null   object
#  8   Distance                7205 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 506.7+ KB

# %%
#convert Year and Distance column from object to float
df_train['Year'] = pd.to_numeric(df_train['Year'],errors='coerce')
df_train['Distance'] = pd.to_numeric(df_train['Distance'],errors='coerce')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7184 non-null   float64
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7188 non-null   float64
#  7   Type                    7008 non-null   object
#  8   Distance                4845 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 506.7+ KB

# %%
df_test['Year'] = pd.to_numeric(df_test['Year'],errors='coerce')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2059 non-null   float64
#  5   Colour     2061 non-null   object
#  6   Type       2007 non-null   object
#  7   Distance   1385 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 128.9+ KB

# %%
year_value = df_train['Year'].mode()[0]
print(year_value)
# Out:
# 2008.0

# %%
df_train['Year'].fillna(year_value, inplace=True)

# %%
amount_value = df_train['Amount (Million Naira)'].mean()
print(round(amount_value, 2))
# Out:
# 11.85

# %%
df_train['Amount (Million Naira)'].fillna(amount_value,inplace=True)

# %%
type_value = df_train['Type'].mode()[0]
print(type_value)
df_train['Type'].fillna(type_value, inplace=True)
# Out:
# Foreign Used

# %%
distance_value = df_train['Distance'].mode()[0]
print(distance_value)
# Out:
# 75000.0

# %%
df_train['Distance'].fillna(distance_value, inplace=True)

# %%
yearTest_value = df_test['Year'].mode()[0]
print(yearTest_value)
# Out:
# 2008.0

# %%
df_test['Year'].fillna(yearTest_value, inplace=True)

# %%
typeTest_value = df_test['Type'].mode()[0]
print(typeTest_value)
df_test['Type'].fillna(typeTest_value,inplace=True)
# Out:
# Foreign Used

# %%
distanceTest_value = df_test['Distance'].mode()[0]
print(distanceTest_value)
df_test['Distance'].fillna(distanceTest_value,inplace=True)
# Out:
# 80000.0

# %%
#checking for missing values
df_train.isnull() .sum()
# Out:
# VehicleID                 0
# Location                  0
# Maker                     0
# Model                     0
# Year                      0
# Colour                    0
# Amount (Million Naira)    0
# Type                      0
# Distance                  0
# dtype: int64

# %%
#checking for missing values
df_test.isnull() .sum()
# Out:
# VehicleID    0
# Location     0
# Maker        0
# Model        0
# Year         0
# Colour       0
# Type         0
# Distance     0
# dtype: int64

# %%
#Categorical Feature for df_train
cat_features = {"VehicleID","Location","Maker","Model","Colour","Type"}
for cat_feature in cat_features:
  print(cat_feature, df_train[cat_feature].unique(), sep=":")
  print("#"*50)
# Out:
# Model:['Accord Coupe EX V-6' 'Sonata' 'RX 350' ... 'Almera 1.6 Lux'
#  'X5 3.0i Sports Activity' '320i SV Premium']
# ##################################################
# Maker:['Honda' 'Hyundai' 'Lexus' 'Mercedes-Benz' 'Toyota' 'Acura' 'Dodge'
#  'Nissan' 'Kia' 'BMW' 'Volvo' 'Ford' 'Land Rover' 'Lincoln' 'Peugeot'
#  'Chevrolet' 'Audi' 'Jaguar' 'Infiniti' 'Porsche' 'Fiat' 'Maserati'
#  'Volkswagen' 'Suzuki' 'Bentley' 'GAC' 'Mazda' 'Scion' 'Renault'
#  'Mitsubishi' 'Mini' 'Pontiac' 'Cadillac' 'Ferrari' 'Jeep' 'Buick'
#  'Rolls-Royce' 'GMC' 'Chrysler' 'Lamborghini' 'Citroen' 'King' 'BAW'
#  'Saturn' 'Tata' 'Opel' 'JAC' 'MG' 'Hummer' 'Subaru' 'Rover' 'Saab'
#  'Skoda' 'IVM' 'Brabus']
# ##################################################
# Type:['Nigerian Used' 'Foreign Used' 'Brand New']
# ##################################################
# VehicleID:['VHL12546' 'VHL18827' 'VHL19499' ... 'VHL12205' 'VHL17562' 'VHL15246']
# ##################################################
# ...

# %%
#Categorical Feature for df_test
cat_features = {"VehicleID","Location","Maker","Model","Colour","Type"}
for cat_feature in cat_features:
  print(cat_feature, df_test[cat_feature].unique(), sep=":")
  print("#"*50)
# Out:
# Model:['323i' 'Camry' 'Highlander Limited V6' 'ES 350 FWD' 'GLE-Class'
#  'Sienna LE 4dr' 'ES 350' 'CR-V' 'RAV4 XLE FWD' 'RX' 'Sequoia'
#  '4-Runner Limited' 'Corolla LE' 'Accord' 'Highlander SE' 'Vibe AWD'
#  'RX 350 F Sport FWD' 'Creta' 'Range Rover Vogue' 'E320'
#  'Land Cruiser Prado' 'Sonata' 'Sienna' '4-Runner Limited 4WD' 'C300'
#  'E350' 'L200 Double Cab 2.5 136hp' 'Avalon XLE Plus (3.5L 6cyl 6A)'
#  '4-Runner' 'RX 330' 'Touareg' 'GX 460 Base' 'GL-Class' 'M Class'
#  'M Class ML 350 4Matic' 'GLK-Class' 'ES' 'Corolla' 'TLX' 'LX 570 Base'
#  'Hilux' 'RX 350' 'IS 350' 'Premacy' 'Venza XLE AWD V6' 'RX 350 AWD'
#  'E300' 'Edge SE 4dr FWD (3.5L 6cyl 6A)' 'Corolla CE' 'Venza AWD' 'Xj'
#  'Zafira' 'Highlander 3' 'Camry SE FWD (2.5L 4cyl 8AM)' 'X5 3.0i'
#  'Genesis' 'RVR' 'X3 xDrive30i AWD' 'Highlander XLE V6 4x2 (3.5L 6cyl 6A)'
#  'RX 300' 'Venza' 'GX 460' 'EX 35' 'S-Class S 63 AMG 4MATIC (W222)'
#  'C-Class C 350 (S204)' 'Venza V6' 'S-Class' 'Sienna LE AWD'
# ...

# %%
#Label Encoding for df_train
cat_features = ["VehicleID","Location","Maker","Model","Colour","Type"]
for cat_feature in cat_features:
  df_train[f"{cat_feature}_cat"] = df_train[cat_feature].astype ("category")
  df_train[f"{cat_feature}_cat"] = df_train[f"{cat_feature}_cat"].cat.codes

# %%
df_train.head(10)
# Out:
#   VehicleID Location          Maker                Model    Year  Colour  \
# 0  VHL12546    Abuja          Honda  Accord Coupe EX V-6  2011.0  Silver
# 1  VHL18827   Ibadan        Hyundai               Sonata  2012.0  Silver
# 2  VHL19499    Lagos          Lexus               RX 350  2010.0     Red
# 3  VHL17991    Abuja  Mercedes-Benz            GLE-Class  2017.0    Blue
# 4  VHL12170   Ibadan         Toyota           Highlander  2002.0     Red
# 5  VHL19996    Lagos         Toyota             Venza V6  2011.0   Black
# 6  VHL16314    Lagos          Lexus           LX 570 AWD  2019.0   Black
# 7  VHL14299    Abuja         Toyota               Avalon  2015.0    Gold
# 8  VHL15637    Lagos         Toyota               Sienna  2012.0    Blue
# 9  VHL15752   Ibadan  Mercedes-Benz            C240 Matt  2004.0   Black
#
#    Amount (Million Naira)           Type  Distance  VehicleID_cat  \
# 0                    2.20  Nigerian Used   75000.0           1317
# ...

# %%
#Label Encoding for df_test
cat_features = ["VehicleID","Location","Maker","Model","Colour","Type"]
for cat_feature in cat_features:
  df_test[f"{cat_feature}_cat"] = df_test[cat_feature].astype ("category")
  df_test[f"{cat_feature}_cat"] = df_test[f"{cat_feature}_cat"].cat.codes

# %%
df_test.head(10)
# Out:
#   VehicleID Location          Maker                  Model    Year Colour  \
# 0  VHL18518    Abuja            BMW                   323i  2008.0  White
# 1  VHL17149    Lagos         Toyota                  Camry  2013.0  White
# 2  VHL10927    Lagos         Toyota  Highlander Limited V6  2005.0   Gold
# 3  VHL12909    Lagos         Toyota                  Camry  2011.0   Gray
# 4  VHL12348    Lagos          Lexus             ES 350 FWD  2013.0    Red
# 5  VHL10798    Lagos  Mercedes-Benz              GLE-Class  2017.0  Black
# 6  VHL11022    Abuja         Toyota          Sienna LE 4dr  1999.0   Gold
# 7  VHL12206    Lagos          Lexus                 ES 350  2011.0    Red
# 8  VHL11697    Abuja          Honda                   CR-V  2017.0  White
# 9  VHL12313    Lagos         Toyota                  Camry  2013.0  Black
#
#            Type  Distance  VehicleID_cat  Location_cat  Maker_cat  Model_cat  \
# ...

# %%
#Drop redundant features for df_train
df_train.drop(["VehicleID","Location","Maker","Model","Colour","Type"], axis = 1, inplace=True)
df_train.head(10)
# Out:
#      Year  Amount (Million Naira)  Distance  VehicleID_cat  Location_cat  \
# 0  2011.0                    2.20   75000.0           1317             0
# 1  2012.0                    3.50  125000.0           4534             1
# 2  2010.0                    9.20  110852.0           4883             2
# 3  2017.0                   22.80   30000.0           4113             0
# 4  2002.0                    2.60  125206.0           1121             1
# 5  2011.0                    7.50   75000.0           5140             2
# 6  2019.0                   79.00   75000.0           3271             2
# 7  2015.0                    9.00   75000.0           2218             0
# 8  2012.0                    7.76  350882.0           2921             2
# 9  2004.0                    2.50  179638.0           2979             1
#
#    Maker_cat  Model_cat  Colour_cat  Type_cat
# 0         17        117          16         2
# 1         19       1049          16         2
# ...

# %%
#Drop redundant features for df_test
df_test.drop(["VehicleID","Location","Maker","Model","Colour","Type"], axis = 1, inplace=True)
df_test.head(10)
# Out:
#      Year  Distance  VehicleID_cat  Location_cat  Maker_cat  Model_cat  \
# 0  2008.0   30524.0           1580             0          2          8
# 1  2013.0   80000.0           1312             2         37        123
# 2  2005.0   80000.0            177             2         37        272
# 3  2011.0  166839.0            523             2         37        123
# 4  2013.0   88862.0            425             2         20        192
# 5  2017.0   69843.0            156             2         24        228
# 6  1999.0   97000.0            193             0         37        488
# 7  2011.0   80000.0            401             2         20        190
# 8  2017.0   80677.0            309             0         12        109
# 9  2013.0   80000.0            415             2         37        123
#
#    Colour_cat  Type_cat
# 0          16         1
# 1          16         1
# 2           7         1
# 3           8         1
# 4          12         1
# 5           2         1
# ...

# %%
#Drop redundant cat object variable features for df_train
df_train.drop(["VehicleID_cat"], axis = 1, inplace=True)
df_train.head(10)
# Out:
#      Year  Amount (Million Naira)  Distance  Location_cat  Maker_cat  \
# 0  2011.0                    2.20   75000.0             0         17
# 1  2012.0                    3.50  125000.0             1         19
# 2  2010.0                    9.20  110852.0             2         29
# 3  2017.0                   22.80   30000.0             0         34
# 4  2002.0                    2.60  125206.0             1         52
# 5  2011.0                    7.50   75000.0             2         52
# 6  2019.0                   79.00   75000.0             2         29
# 7  2015.0                    9.00   75000.0             0         52
# 8  2012.0                    7.76  350882.0             2         52
# 9  2004.0                    2.50  179638.0             1         34
#
#    Model_cat  Colour_cat  Type_cat
# 0        117          16         2
# 1       1049          16         2
# 2        908          15         1
# 3        508           2         1
# ...

# %%
#Drop redundant cat object variable features for df_test
df_test.drop(["VehicleID_cat"], axis = 1, inplace=True)
df_test.head(10)
# Out:
#      Year  Distance  Location_cat  Maker_cat  Model_cat  Colour_cat  Type_cat
# 0  2008.0   30524.0             0          2          8          16         1
# 1  2013.0   80000.0             2         37        123          16         1
# 2  2005.0   80000.0             2         37        272           7         1
# 3  2011.0  166839.0             2         37        123           8         1
# 4  2013.0   88862.0             2         20        192          12         1
# 5  2017.0   69843.0             2         24        228           2         1
# 6  1999.0   97000.0             0         37        488           7         1
# 7  2011.0   80000.0             2         20        190          12         1
# 8  2017.0   80677.0             0         12        109          16         1
# 9  2013.0   80000.0             2         37        123           2         1

# %%
#data prediction
y = df_train["Amount (Million Naira)"] # Target
x = df_train.drop("Amount (Million Naira)", axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.286)

# %%
#Loading the dataset into Linear Regression algorithm
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
#Making predictions
real_prediction = reg.predict(x_test)
print(real_prediction)
# Out:
# [21.34792506 11.14345069 21.8625692  ...  6.64343848 16.74636249
#  -1.91632162]

# %%
test_prediction = reg.predict(df_test)
print(test_prediction)
# Out:
# [ 6.99234431 11.47729641 -1.56300453 ... 20.13457427 17.73842504
#  11.8037687 ]

# %%
df_test.head()
# Out:
#      Year  Distance  Location_cat  Maker_cat  Model_cat  Colour_cat  Type_cat
# 0  2008.0   30524.0             0          2          8          16         1
# 1  2013.0   80000.0             2         37        123          16         1
# 2  2005.0   80000.0             2         37        272           7         1
# 3  2011.0  166839.0             2         37        123           8         1
# 4  2013.0   88862.0             2         20        192          12         1

# %%
from sklearn.metrics import mean_squared_error
import math

rmse = math.sqrt(mean_squared_error(test_prediction, real_prediction))
print (rmse)
# Out:
# 18.03108845421151

# %%
sample_file = pd.read_csv("/content/drive/MyDrive/DSN_TASK 1/SampleSubmission.csv")
sample_file.head()
# Out:
#   VehicleID  Amount (Million Naira)
# 0  VHL18518                     1.0
# 1  VHL17149                     1.0
# 2  VHL10927                     1.0
# 3  VHL12909                     1.0
# 4  VHL12348                     1.0

# %%
#the sample_file size
print (len(sample_file))
# Out:
# 2061

# %%
#replacing the sample_file with the test_prediction value
sample_file["Amount (Million Naira)"] = test_prediction
sample_file.head()
# Out:
#   VehicleID  Amount (Million Naira)
# 0  VHL18518                6.992344
# 1  VHL17149               11.477296
# 2  VHL10927               -1.563005
# 3  VHL12909                9.537806
# 4  VHL12348               13.808432

# %%
sample_file.to_csv("/content/drive/MyDrive/DSN_TASK 1/OLALERE_1ST_SUBMISSION.csv", index=False)
